# %% [markdown]
# **Import Libaries and data**

# %%
import numpy as np # linear algebra operations
import pandas as pd # used for data preparation
import plotly.express as px #used for data visualization
from textblob import TextBlob #used for sentiment analysis

df = pd.read_csv('/content/disney_plus_titles.csv')
df
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %% [markdown]
# ## Checking number of rows and columns in data

# %%
df.shape
# Out:
# (1450, 12)

# %% [markdown]
# # Checking content available in Dataset

# %%
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %% [markdown]
# #How to check columns name of dataset

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# #Taking the count of ratings available

# %%
x = df.groupby(['rating']).size().reset_index(name='counts')
print(x)
# Out:
#      rating  counts
# 0         G     253
# 1        PG     236
# 2     PG-13      66
# 3     TV-14      79
# 4      TV-G     318
# 5     TV-PG     301
# 6      TV-Y      50
# 7     TV-Y7     131
# 8  TV-Y7-FV      13

# %% [markdown]
# #Creating the Piechart based on Content rating

# %%
pieChart = px.pie(x, values='counts', names='rating', title='Distribution of content ratings on Disney+')
pieChart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Analyzing the top 5 Directors on Disney+

# %%
df['director']=df['director'].fillna('Director not specified')
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4             Director not specified
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
directors_list = pd.DataFrame()
print(directors_list)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
directors_list = df['director'].str.split(',', expand=True).stack()
print(directors_list)
# Out:
# 0     0    Alonso Ramirez Ramos
#       1             Dave Wasson
# 1     0             John Cherry
# 2     0            Karen Disher
# 3     0         Hamish Hamilton
#                    ...
# 1445  0              Gavin Hood
# 1446  0              Shawn Levy
# 1447  0         Dexter Fletcher
# 1448  0         Gurinder Chadha
# 1449  0             Mark Waring
# Length: 1594, dtype: object

# %%
directors_list = directors_list.to_frame()
print(directors_list)
# Out:
#                            0
# 0    0  Alonso Ramirez Ramos
#      1           Dave Wasson
# 1    0           John Cherry
# 2    0          Karen Disher
# 3    0       Hamish Hamilton
# ...                      ...
# 1445 0            Gavin Hood
# 1446 0            Shawn Levy
# 1447 0       Dexter Fletcher
# 1448 0       Gurinder Chadha
# 1449 0           Mark Waring
#
# [1594 rows x 1 columns]

# %%
directors_list.columns = ['Director']
print(directors_list)
# Out:
#                     Director
# 0    0  Alonso Ramirez Ramos
#      1           Dave Wasson
# 1    0           John Cherry
# 2    0          Karen Disher
# 3    0       Hamish Hamilton
# ...                      ...
# 1445 0            Gavin Hood
# 1446 0            Shawn Levy
# 1447 0       Dexter Fletcher
# 1448 0       Gurinder Chadha
# 1449 0           Mark Waring
#
# [1594 rows x 1 columns]

# %%
directors = directors_list.groupby(['Director']).size().reset_index(name='Total Count')
print(directors)
# Out:
#             Director  Total Count
# 0       Alan Zaslove            1
# 1     Andrew Jimenez            1
# 2         Andy Byatt            1
# 3      Angus MacLane            1
# 4        Art Stevens            1
# ..               ...          ...
# 669  Zach A. Parrish            1
# 670      Zak Knutson            1
# 671         Zhong Yu            1
# 672      Érik Canuel            1
# 673             朱家欣             1
#
# [674 rows x 2 columns]

# %%
directors = directors[directors.Director != 'Director not specified']

# %%
print(directors)
# Out:
#             Director  Total Count
# 0       Alan Zaslove            1
# 1     Andrew Jimenez            1
# 2         Andy Byatt            1
# 3      Angus MacLane            1
# 4        Art Stevens            1
# ..               ...          ...
# 669  Zach A. Parrish            1
# 670      Zak Knutson            1
# 671         Zhong Yu            1
# 672      Érik Canuel            1
# 673             朱家欣             1
#
# [673 rows x 2 columns]

# %%
directors = directors.sort_values(by=['Total Count'], ascending = False)
print(directors)
# Out:
#              Director  Total Count
# 318       Jack Hannah           17
# 377     John Lasseter           16
# 515         Paul Hoen           16
# 663   Wilfred Jackson           14
# 559  Robert Stevenson           12
# ..                ...          ...
# 249      Donovan Cook            1
# 248     Donald Petrie            1
# 243         Domee Shi            1
# 241      Dick Rickard            1
# 673              朱家欣             1
#
# [673 rows x 2 columns]

# %%
top5Directors = directors.head()
print(top5Directors)
# Out:
#              Director  Total Count
# 318       Jack Hannah           17
# 377     John Lasseter           16
# 515         Paul Hoen           16
# 663   Wilfred Jackson           14
# 559  Robert Stevenson           12

# %%
top5Directors = top5Directors.sort_values(by=['Total Count'])
barChart = px.bar(top5Directors, x='Total Count', y = 'Director', title = 'Top 5 Directors on Disney+')
barChart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Analyzing the top 5 Actors on Disney+

# %%
df['cast']=df['cast'].fillna('No cast specified')
cast_df = pd.DataFrame()
cast_df = df['cast'].str.split(',',expand=True).stack()
cast_df = cast_df.to_frame()
cast_df.columns = ['Actor']
actors = cast_df.groupby(['Actor']).size().reset_index(name = 'Total Count')
actors = actors[actors.Actor != 'No cast specified']
actors = actors.sort_values(by=['Total Count'], ascending=False)
top5Actors = actors.head()
top5Actors = top5Actors.sort_values(by=['Total Count'])
barChart2 = px.bar(top5Actors, x='Total Count', y='Actor', title='Top 5 Actors on Disney+')
barChart2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Analyzing the content produced on Disney+ based on years

# %%
df1 = df[['type', 'release_year']]
df1 = df1.rename(columns = {"release_year":"Release Year", "type": "Type"})
df2 = df1.groupby(['Release Year', 'Type']).size().reset_index(name='Total Count')

# %%
print(df2)
# Out:
#      Release Year     Type  Total Count
# 0            1928    Movie            1
# 1            1932    Movie            3
# 2            1933    Movie            3
# 3            1934    Movie            4
# 4            1935    Movie            4
# ..            ...      ...          ...
# 125          2019  TV Show           38
# 126          2020    Movie           74
# 127          2020  TV Show           40
# 128          2021    Movie           70
# 129          2021  TV Show           55
#
# [130 rows x 3 columns]

# %%
df2 = df2[df2['Release Year']>=2000]
graph = px.line(df2, x = "Release Year", y="Total Count", color = "Type", title = "Trend of Content Produced on Disney+ Every Year")
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Sentiment Analysis of Disney+ Content

# %%
df3 = df[['release_year', 'description']]
df3 = df3.rename(columns = {'release_year':'Release Year', 'description':'Description'})
for index, row in df3.iterrows():
  d=row['Description']
  testimonial = TextBlob(d)
  p = testimonial.sentiment.polarity
  if p==0:
    sent = 'Neutral'
  elif p>0:
    sent = 'Positive'
  else:
    sent = 'Negative'
  df3.loc[[index, 2], 'Sentiment']=sent

df3 = df3.groupby(['Release Year', 'Sentiment']).size().reset_index(name = 'Total Count')

df3 = df3[df3['Release Year']>2005]
barGraph = px.bar(df3, x="Release Year", y="Total Count", color = "Sentiment", title = "Sentiment Analysis of Content on Disney+")
barGraph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
